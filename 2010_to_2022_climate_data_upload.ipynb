# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
import os
import pandas as pd
from urllib.parse import urljoin

# %%
from bs4 import BeautifulSoup

def get_csv_urls_temp(base_url):
    csv_urls_temp = []

    # Loop through the years
    for year in range(2010, 2023):
        year_url = urljoin(base_url, f"{year}/")
        response = requests.get(year_url)
        if response.status_code == 200:
            # Use BeautifulSoup to parse the HTML
            soup = BeautifulSoup(response.text, 'html.parser')
            # Find all links (or other relevant tags) pointing to CSV files
            for link in soup.find_all('a'):
                href = link.get('href')
                if href.endswith('water_temperature.csv'):
                    csv_file_url = urljoin(year_url, href)
                    csv_urls_temp.append(csv_file_url)
        else:
            print(f"Failed to access folder for year {year}")

    return csv_urls_temp


def download_and_combine_csvs_temp(csv_urls):
    """
    Function to download CSVs from a list of URLs and combine them into a single DataFrame.
    """
    df_list_temp = []

    for url in csv_urls_temp:
        print(f"Downloading: {url}")
        response = requests.get(url)
        if response.status_code == 200:
            # Read the CSV content into a DataFrame
            df_temp = pd.read_csv(url)
            df_list_temp.append(df_temp)
        else:
            print(f"Failed to download: {url}")

    # Combine all DataFrames into one
    combined_df_temp = pd.concat(df_list_temp, ignore_index=True)
    return combined_df_temp

# URL of the base directory containing the year folders
base_url = "https://data.gcoos.org/data/waf/csv_by_observation/"

# Get the list of CSV URLs from the website
csv_urls_temp = get_csv_urls_temp(base_url)

# Download the CSVs and combine them into one DataFrame
combined_watertemp = download_and_combine_csvs_temp(csv_urls_temp)

# Display or save the combined DataFrame
print(combined_watertemp)
# Out:
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_03_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_04_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_05_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_06_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_07_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_08_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_09_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_10_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_11_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_12_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_01_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_02_sea_water_temperature.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_03_sea_water_temperature.csv
#                                                     network  \
# 0                                                     COAPS
# 1                                                     COMPS
# 2                                                     COMPS
# 3                                                      DISL
# 4                                                       ENP
# ...                                                     ...
# 18487959                                                NOS
# 18487960                                                NOS
# 18487961                                                NOS
# 18487962                                                NOS
# 18487963  DISCLAIMER: The Gulf of Mexico Coastal and Oce...
#
#                                       platform  latitude  longitude  \
# 0                        ioos:station:COAPS:N7   29.6619   -84.3731
# 1                   ioos:station:USF.COMPS:ANC   28.1930   -82.7890
# 2                   ioos:station:USF.COMPS:EGK   27.6010   -82.7510
# 3                       ioos:station:DISL:CATA   30.3085   -88.1395
# 4                 ioos.station.NOAA.NDBC:DKKF1   25.1800   -80.4900
# ...                                        ...       ...        ...
# 18487959  ioos:station:NOAA.NOS.CO-OPS:8774770   28.0217   -97.0467
# 18487960  ioos:station:NOAA.NOS.CO-OPS:8775244   27.8328   -97.4859
# 18487961  ioos:station:NOAA.NOS.CO-OPS:8775296   27.8120   -97.3900
# 18487962  ioos:station:NOAA.NOS.CO-OPS:8779770   26.0600   -97.2150
# 18487963                                   NaN       NaN        NaN
#
#                           date  vertical_datum  sea_water_temperature  \
# 0         2010-01-01T00:00:00Z             1.0                 439.10
# 1         2010-01-01T00:00:00Z            -1.0                  15.97
# 2         2010-01-01T00:00:00Z            -1.0                   9.13
# 3         2010-01-01T00:00:00Z             0.0                  11.56
# 4         2010-01-01T00:00:00Z             1.0                  19.30
# ...                        ...             ...                    ...
# 18487959  2021-03-31T23:54:00Z             0.0                    NaN
# 18487960  2021-03-31T23:54:00Z            -1.0                    NaN
# 18487961  2021-03-31T23:54:00Z            -1.0                    NaN
# 18487962  2021-03-31T23:54:00Z             0.0                    NaN
# 18487963                   NaN             NaN                    NaN
#
#              qcFlag   sea_water_temperature
# 0                2.0                     NaN
# 1                2.0                     NaN
# 2                2.0                     NaN
# 3                2.0                     NaN
# 4         11111222.0                     NaN
# ...              ...                     ...
# 18487959         NaN                    22.1
# 18487960         NaN                    22.6
# 18487961         NaN                    22.5
# 18487962         NaN                    22.3
# 18487963         NaN                     NaN
#
# [18487964 rows x 9 columns]

# %%
def get_csv_urls_salinity(base_url):
    csv_urls_salinity = []

    # Loop through the years
    for year in range(2010, 2023):
        year_url = urljoin(base_url, f"{year}/")
        response = requests.get(year_url)
        if response.status_code == 200:
            # Use BeautifulSoup to parse the HTML
            soup = BeautifulSoup(response.text, 'html.parser')
            # Find all links (or other relevant tags) pointing to CSV files
            for link in soup.find_all('a'):
                href = link.get('href')
                if href.endswith('salinity.csv'):
                    csv_file_url = urljoin(year_url, href)
                    csv_urls_salinity.append(csv_file_url)
        else:
            print(f"Failed to access folder for year {year}")

    return csv_urls_salinity


def download_and_combine_csvs_salinity(csv_urls_salinity):
    """
    Function to download CSVs from a list of URLs and combine them into a single DataFrame.
    """
    df_list_salinity = []

    for url in csv_urls_salinity:
        print(f"Downloading: {url}")
        response = requests.get(url)
        if response.status_code == 200:
            # Read the CSV content into a DataFrame
            df_salinity = pd.read_csv(url)
            df_list_salinity.append(df_salinity)
        else:
            print(f"Failed to download: {url}")

    # Combine all DataFrames into one
    combined_df_salinity = pd.concat(df_list_salinity, ignore_index=True)
    return combined_df_salinity

# URL of the base directory containing the year folders
base_url = "https://data.gcoos.org/data/waf/csv_by_observation/"

# Get the list of CSV URLs from the website
csv_urls_salinity = get_csv_urls_salinity(base_url)

# Download the CSVs and combine them into one DataFrame
combined_salinity = download_and_combine_csvs_salinity(csv_urls_salinity)

# Display or save the combined DataFrame
print(combined_salinity)
# Out:
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_03_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_04_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_05_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_06_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_07_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_08_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_09_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_10_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_11_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_12_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_01_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_02_sea_water_practical_salinity.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_03_sea_water_practical_salinity.csv
#                                                    network  \
# 0                                                    COMPS
# 1                                                     DISL
# 2                                                      ENP
# 3                                                      ENP
# 4                                               SCCF RECON
# ...                                                    ...
# 7033547                                                NOS
# 7033548                                                NOS
# 7033549                                                NOS
# 7033550                                                NOS
# 7033551  DISCLAIMER: The Gulf of Mexico Coastal and Oce...
#
#                                      platform  latitude  longitude  \
# 0                  ioos:station:USF.COMPS:ANC   28.1930   -82.7890
# 1                      ioos:station:DISL:CATA   30.3085   -88.1395
# 2                ioos.station.NOAA.NDBC:DKKF1   25.1800   -80.4900
# 3                ioos.station.NOAA.NDBC:LBRF1   25.4840   -81.1330
# 4                        ioos:station:SCCF:12   26.4966   -82.1479
# ...                                       ...       ...        ...
# 7033547  ioos:station:NOAA.NOS.CO-OPS:8770613   29.6817   -94.9850
# 7033548  ioos:station:NOAA.NOS.CO-OPS:8737048   30.7083   -88.0433
# 7033549  ioos:station:NOAA.NOS.CO-OPS:8764314   29.2675   -91.3839
# 7033550  ioos:station:NOAA.NOS.CO-OPS:8770613   29.6817   -94.9850
# 7033551                                   NaN       NaN        NaN
#
#                          date  vertical_datum  sea_water_practical_salinity  \
# 0        2010-01-01T00:00:00Z            1.00                        17.553
# 1        2010-01-01T00:00:00Z            2.81                         1.760
# 2        2010-01-01T00:00:00Z            1.50                        30.300
# 3        2010-01-01T00:00:00Z            1.50                        19.700
# 4        2010-01-01T00:00:00Z            2.39                        32.990
# ...                       ...             ...                           ...
# 7033547  2021-03-31T23:48:00Z            1.00                           NaN
# 7033548  2021-03-31T23:54:00Z            1.00                           NaN
# 7033549  2021-03-31T23:54:00Z            1.00                           NaN
# 7033550  2021-03-31T23:54:00Z            1.00                           NaN
# 7033551                   NaN             NaN                           NaN
#
#             qcFlag   sea_water_practical_salinity
# 0         1111122.0                            NaN
# 1         1111122.0                            NaN
# 2        11111222.0                            NaN
# 3        11111222.0                            NaN
# 4         1111122.0                            NaN
# ...             ...                            ...
# 7033547         NaN                          13.93
# 7033548         NaN                           0.61
# 7033549         NaN                           0.13
# 7033550         NaN                          14.70
# 7033551         NaN                            NaN
#
# [7033552 rows x 9 columns]

# %%
print(combined_watertemp.columns)
print(combined_salinity.columns)
# Out:
# Index(['network', 'platform', 'latitude', 'longitude', 'date',
#        'vertical_datum', 'sea_water_temperature', 'qcFlag ',
#        'sea_water_temperature '],
#       dtype='object')
# Index(['network', 'platform', 'latitude', 'longitude', 'date',
#        'vertical_datum', 'sea_water_practical_salinity', 'qcFlag ',
#        'sea_water_practical_salinity '],
#       dtype='object')

# %%
# Combine the two 'sea_water_temperature' columns
combined_watertemp['sea_water_temperature_combined'] = combined_watertemp['sea_water_temperature'].fillna(combined_watertemp['sea_water_temperature '])

# Now, drop the old columns if they are no longer needed
combined_watertemp = combined_watertemp.drop(['sea_water_temperature', 'sea_water_temperature '], axis=1)

# Rename the new combined column (optional)
combined_watertemp = combined_watertemp.rename(columns={'sea_water_temperature_combined': 'sea_water_temperature'})

# Display the updated DataFrame
print(combined_watertemp.head())
# Out:
#   network                      platform  latitude  longitude  \
# 0   COAPS         ioos:station:COAPS:N7   29.6619   -84.3731
# 1   COMPS    ioos:station:USF.COMPS:ANC   28.1930   -82.7890
# 2   COMPS    ioos:station:USF.COMPS:EGK   27.6010   -82.7510
# 3    DISL        ioos:station:DISL:CATA   30.3085   -88.1395
# 4     ENP  ioos.station.NOAA.NDBC:DKKF1   25.1800   -80.4900
#
#                    date  vertical_datum     qcFlag   sea_water_temperature
# 0  2010-01-01T00:00:00Z             1.0         2.0                 439.10
# 1  2010-01-01T00:00:00Z            -1.0         2.0                  15.97
# 2  2010-01-01T00:00:00Z            -1.0         2.0                   9.13
# 3  2010-01-01T00:00:00Z             0.0         2.0                  11.56
# 4  2010-01-01T00:00:00Z             1.0  11111222.0                  19.30

# %%
# Combine the two 'sea_water_practical_salinity' columns
combined_salinity['sea_water_practical_salinity_combined'] = combined_salinity['sea_water_practical_salinity'].fillna(combined_salinity['sea_water_practical_salinity '])

# Now, drop the old columns if they are no longer needed
combined_salinity = combined_salinity.drop(['sea_water_practical_salinity', 'sea_water_practical_salinity '], axis=1)

# Rename the new combined column (optional)
combined_salinity = combined_salinity.rename(columns={'sea_water_practical_salinity_combined': 'sea_water_practical_salinity'})

# Display the updated DataFrame
print(combined_salinity.head())
# Out:
#       network                      platform  latitude  longitude  \
# 0       COMPS    ioos:station:USF.COMPS:ANC   28.1930   -82.7890
# 1        DISL        ioos:station:DISL:CATA   30.3085   -88.1395
# 2         ENP  ioos.station.NOAA.NDBC:DKKF1   25.1800   -80.4900
# 3         ENP  ioos.station.NOAA.NDBC:LBRF1   25.4840   -81.1330
# 4  SCCF RECON          ioos:station:SCCF:12   26.4966   -82.1479
#
#                    date  vertical_datum     qcFlag   \
# 0  2010-01-01T00:00:00Z            1.00   1111122.0
# 1  2010-01-01T00:00:00Z            2.81   1111122.0
# 2  2010-01-01T00:00:00Z            1.50  11111222.0
# 3  2010-01-01T00:00:00Z            1.50  11111222.0
# 4  2010-01-01T00:00:00Z            2.39   1111122.0
#
#    sea_water_practical_salinity
# 0                        17.553
# 1                         1.760
# 2                        30.300
# 3                        19.700
# 4                        32.990

# %%
def get_csv_urls_oxygen(base_url):
    csv_urls_oxygen = []

    # Loop through the years
    for year in range(2010, 2023):
        year_url = urljoin(base_url, f"{year}/")
        response = requests.get(year_url)
        if response.status_code == 200:
            # Use BeautifulSoup to parse the HTML
            soup = BeautifulSoup(response.text, 'html.parser')
            # Find all links (or other relevant tags) pointing to CSV files
            for link in soup.find_all('a'):
                href = link.get('href')
                if href.endswith('oxygen_in_sea_water.csv'):
                    csv_file_url = urljoin(year_url, href)
                    csv_urls_oxygen.append(csv_file_url)
        else:
            print(f"Failed to access folder for year {year}")

    return csv_urls_oxygen


def download_and_combine_csvs_oxygen(csv_urls):
    """
    Function to download CSVs from a list of URLs and combine them into a single DataFrame.
    """
    df_list_oxygen = []

    for url in csv_urls_oxygen:
        print(f"Downloading: {url}")
        response = requests.get(url)
        if response.status_code == 200:
            # Read the CSV content into a DataFrame
            df_oxygen = pd.read_csv(url)
            df_list_oxygen.append(df_oxygen)
        else:
            print(f"Failed to download: {url}")

    # Combine all DataFrames into one
    combined_df_oxygen = pd.concat(df_list_oxygen, ignore_index=True)
    return combined_df_oxygen

# URL of the base directory containing the year folders
base_url = "https://data.gcoos.org/data/waf/csv_by_observation/"

# Get the list of CSV URLs from the website
csv_urls_oxygen = get_csv_urls_oxygen(base_url)

# Download the CSVs and combine them into one DataFrame
combined_oxygen = download_and_combine_csvs_oxygen(csv_urls_oxygen)

# Display or save the combined DataFrame
print(combined_oxygen)
# Out:
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2010/gcoos_2010_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2011/gcoos_2011_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2012/gcoos_2012_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2013/gcoos_2013_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2014/gcoos_2014_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2015/gcoos_2015_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2016/gcoos_2016_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2017/gcoos_2017_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2018/gcoos_2018_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2019/gcoos_2019_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2020/gcoos_2020_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_07_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2021/gcoos_2021_12_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_01_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_02_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_03_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_04_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_05_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_06_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_08_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_09_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_10_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_11_mass_concentration_of_oxygen_in_sea_water.csv
# Downloading: https://data.gcoos.org/data/waf/csv_by_observation/2022/gcoos_2022_12_mass_concentration_of_oxygen_in_sea_water.csv
#                                                    network  \
# 0                                                     DISL
# 1                                               SCCF RECON
# 2                                               SCCF RECON
# 3                                               SCCF RECON
# 4                                               SCCF RECON
# ...                                                    ...
# 2779090                                              TCOON
# 2779091                                              TCOON
# 2779092                                              TCOON
# 2779093                                             LUMCON
# 2779094  DISCLAIMER: The Gulf of Mexico Coastal and Oce...
#
#                         platform  latitude  longitude                  date  \
# 0         ioos:station:DISL:CATA   30.3085   -88.1395  2010-01-01T00:00:00Z
# 1           ioos:station:SCCF:12   26.4966   -82.1479  2010-01-01T00:00:00Z
# 2           ioos:station:SCCF:13   26.5255   -82.0032  2010-01-01T00:00:00Z
# 3           ioos:station:SCCF:16   26.4345   -81.9647  2010-01-01T00:00:00Z
# 4           ioos:station:SCCF:51   26.5545   -82.1715  2010-01-01T00:00:00Z
# ...                          ...       ...        ...                   ...
# 2779090   ioos:station:TCOON:127   28.2598   -96.7737  2022-12-31T23:30:00Z
# 2779091   ioos:station:TCOON:170   27.2970   -97.4049  2022-12-31T23:30:00Z
# 2779092   ioos:station:TCOON:171   27.4847   -97.3181  2022-12-31T23:30:00Z
# 2779093  ioos:station:LUMCON:101   29.2533   -90.6633  2022-12-31T23:45:00Z
# 2779094                      NaN       NaN        NaN                   NaN
#
#          vertical_datum  mass_concentration_of_oxygen_in_sea_wate    qcFlag   \
# 0                 2.810                                     10.79  1111122.0
# 1                 2.390                                      6.97  1111122.0
# 2                 2.470                                      7.64  1111122.0
# 3                 2.623                                      7.69  1111122.0
# 4                 1.986                                      8.00  1111122.0
# ...                 ...                                       ...        ...
# 2779090           1.000                                       NaN        NaN
# 2779091           1.000                                       NaN        NaN
# 2779092           1.000                                       NaN        NaN
# 2779093          16.910                                       NaN        NaN
# 2779094             NaN                                       NaN        NaN
#
#          mass_concentration_of_oxygen_in_sea_water
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2779090                                       14.12
# 2779091                                        9.37
# 2779092                                        9.97
# 2779093                                        9.37
# 2779094                                         NaN
#
# [2779095 rows x 9 columns]

# %%
print(combined_oxygen.columns)
# Out:
# Index(['network', 'platform', 'latitude', 'longitude', 'date',
#        'vertical_datum', 'mass_concentration_of_oxygen_in_sea_wate', 'qcFlag ',
#        'mass_concentration_of_oxygen_in_sea_water '],
#       dtype='object')

# %%
# Combine the two 'mass_concentration_of_oxygen_in_sea_water' columns
combined_oxygen['mass_concentration_of_oxygen_in_sea_water_combined'] = combined_oxygen['mass_concentration_of_oxygen_in_sea_wate'].fillna(combined_oxygen['mass_concentration_of_oxygen_in_sea_water '])

# Now, drop the old columns if they are no longer needed
combined_oxygen = combined_oxygen.drop(['mass_concentration_of_oxygen_in_sea_wate', 'mass_concentration_of_oxygen_in_sea_water '], axis=1)

# Rename the new combined column (optional)
combined_oxygen = combined_oxygen.rename(columns={'mass_concentration_of_oxygen_in_sea_water_combined': 'mass_concentration_of_oxygen_in_sea_water'})

# Display the updated DataFrame
print(combined_oxygen.head())
# Out:
#       network                platform  latitude  longitude  \
# 0        DISL  ioos:station:DISL:CATA   30.3085   -88.1395
# 1  SCCF RECON    ioos:station:SCCF:12   26.4966   -82.1479
# 2  SCCF RECON    ioos:station:SCCF:13   26.5255   -82.0032
# 3  SCCF RECON    ioos:station:SCCF:16   26.4345   -81.9647
# 4  SCCF RECON    ioos:station:SCCF:51   26.5545   -82.1715
#
#                    date  vertical_datum    qcFlag   \
# 0  2010-01-01T00:00:00Z           2.810  1111122.0
# 1  2010-01-01T00:00:00Z           2.390  1111122.0
# 2  2010-01-01T00:00:00Z           2.470  1111122.0
# 3  2010-01-01T00:00:00Z           2.623  1111122.0
# 4  2010-01-01T00:00:00Z           1.986  1111122.0
#
#    mass_concentration_of_oxygen_in_sea_water
# 0                                      10.79
# 1                                       6.97
# 2                                       7.64
# 3                                       7.69
# 4                                       8.00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
#     278     elif case == 4:
#     279       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
combined_watertemp.to_csv('/content/drive/My Drive/DAT 490 Capstone/Data/water temp.csv', index=False)

# %%
combined_salinity.to_csv('/content/drive/My Drive/DAT 490 Capstone/Data/salinity.csv', index=False)

# %%
combined_oxygen.to_csv('/content/drive/My Drive/DAT 490 Capstone/Data/oxygen.csv', index=False)
